# %% [markdown]
# # **IMPORT LIBRARY**

# %%
import requests
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **DATASET**

# %% [markdown]
# *Dataset* dapat diakses pada tautan berikut ini.
#
# *   https://drive.google.com/file/d/1VUIeb380DGdK9CIY9rpI1zXt7eVvA5vP/view?usp=sharing

# %%
# load dataset
df = pd.read_csv("/content/drive/MyDrive/MK SISTEM REKOMENDASI/DatasetLagu.csv")
df
# Out:
#                      Artis              Judul  \
# 0                     Niki  Ocean and Engines
# 1            Taylor Swift             August
# 2           One Direction      Steal My Girl
# 3                 The 1975           Robbers
# 4        Rex Orange County    Pluto Projector
# ..                     ...                ...
# 73   Red Hot Chili Peppers    Soul To Squeeze
# 74             Post Malone           Chemical
# 75  Michael Learns to Rock          The Actor
# 76                Bon Jovi       It's my life
# 77       Avenged Sevenfold        Danger line
#
#                                                 Lirik
# 0   Saturday sunset\nWe're lying on my bed with fi...
# 1   Salt air, and the rust on your door\nI never n...
# 2   She's been my queen since we were sixteen\nWe ...
# 3   She had a face straight outta magazine\nGod on...
# 4   [Verse 1]\nThe great protector\nIs that what I...
# ..                                                ...
# 73  I got a bad disease\nOut from my brain is wher...
# 74  Oxytocin makin' it all okay\nWhen I come back ...
# 75  He takes you out and he takes you up\n'Cause h...
# 76  This ain't a song for the broken-hearted\r\nNo...
# 77  My 16 locked and loaded\r\nAll fear has been a...
#
# [78 rows x 3 columns]

# %% [markdown]
# # **TF-IDF**

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
# vektorizer TF-IDF untuk mengubah fitur teks menjadi vektor numerik
tfidf = TfidfVectorizer(stop_words='english')

# menerapkan vektorisasi TF-IDF
tfidf_matrix = tfidf.fit_transform(df['Judul'].fillna('') + ' ' + df['Lirik'].fillna(''))

# %%
feature_names = tfidf.get_feature_names_out()
tfidf_values = tfidf_matrix.toarray()

# nilai rata-rata TF-IDF untuk setiap kata
avg_tfidf_values = np.mean(tfidf_values, axis=0)

# indeks 100
top_100_indices = np.argsort(avg_tfidf_values)[-100:]
top_100_words = [feature_names[i] for i in top_100_indices]

for word, tfidf_value in zip(top_100_words, avg_tfidf_values[top_100_indices]):
    print(f'Kata "{word}" memiliki nilai rata-rata TF-IDF {tfidf_value}')
# Out:
# Kata "whoa" memiliki nilai rata-rata TF-IDF 0.010185981933434108
# Kata "place" memiliki nilai rata-rata TF-IDF 0.010234842071486675
# Kata "better" memiliki nilai rata-rata TF-IDF 0.010280692386593735
# Kata "sky" memiliki nilai rata-rata TF-IDF 0.010438419896461982
# Kata "sing" memiliki nilai rata-rata TF-IDF 0.01050196396918566
# Kata "forget" memiliki nilai rata-rata TF-IDF 0.010543071876727891
# Kata "chorus" memiliki nilai rata-rata TF-IDF 0.010640208737729842
# Kata "loved" memiliki nilai rata-rata TF-IDF 0.011037686660093074
# Kata "song" memiliki nilai rata-rata TF-IDF 0.011057521498265119
# Kata "door" memiliki nilai rata-rata TF-IDF 0.01106190191573084
# Kata "pretty" memiliki nilai rata-rata TF-IDF 0.011077513277280682
# Kata "good" memiliki nilai rata-rata TF-IDF 0.011140112250954163
# Kata "line" memiliki nilai rata-rata TF-IDF 0.011171856619989212
# Kata "hard" memiliki nilai rata-rata TF-IDF 0.011233265382245691
# Kata "bothering" memiliki nilai rata-rata TF-IDF 0.011248192812568333
# Kata "perfect" memiliki nilai rata-rata TF-IDF 0.01125285425059112
# Kata "august" memiliki nilai rata-rata TF-IDF 0.011338207213477919
# Kata "little" memiliki nilai rata-rata TF-IDF 0.01150063958182514
# Kata "thank" memiliki nilai rata-rata TF-IDF 0.011737763892252577
# Kata "live" memiliki nilai rata-rata TF-IDF 0.01174605596613275
# Kata "turn" memiliki nilai rata-rata TF-IDF 0.011780062985070712
# Kata "new" memiliki nilai rata-rata TF-IDF 0.011866380301874499
# Kata "times" memiliki nilai rata-rata TF-IDF 0.011899554247368745
# Kata "touch" memiliki nilai rata-rata TF-IDF 0.01201131912976999
# Kata "hate" memiliki nilai rata-rata TF-IDF 0.01203190691682236
# Kata "long" memiliki nilai rata-rata TF-IDF 0.012166242360971401
# Kata "things" memiliki nilai rata-rata TF-IDF 0.012182238048174253
# Kata "chance" memiliki nilai rata-rata TF-IDF 0.01220538665643274
# Kata "thing" memiliki nilai rata-rata TF-IDF 0.012340250885813114
# Kata "close" memiliki nilai rata-rata TF-IDF 0.012446748310631571
# Kata "wrong" memiliki nilai rata-rata TF-IDF 0.012462071163020508
# Kata "amazing" memiliki nilai rata-rata TF-IDF 0.01266699030038321
# Kata "ain" memiliki nilai rata-rata TF-IDF 0.012830461930866593
# Kata "lost" memiliki nilai rata-rata TF-IDF 0.012848174916671987
# Kata "stand" memiliki nilai rata-rata TF-IDF 0.012937489177109395
# Kata "sleepwalking" memiliki nilai rata-rata TF-IDF 0.013109997847944617
# Kata "moonlight" memiliki nilai rata-rata TF-IDF 0.013130325099812837
# Kata "friend" memiliki nilai rata-rata TF-IDF 0.013189929464487129
# Kata "did" memiliki nilai rata-rata TF-IDF 0.013196396377101544
# Kata "light" memiliki nilai rata-rata TF-IDF 0.013222518114470675
# Kata "home" memiliki nilai rata-rata TF-IDF 0.013454846966071007
# Kata "change" memiliki nilai rata-rata TF-IDF 0.013586955078974623
# Kata "life" memiliki nilai rata-rata TF-IDF 0.01387077695338943
# Kata "round" memiliki nilai rata-rata TF-IDF 0.013948944422804229
# Kata "leave" memiliki nilai rata-rata TF-IDF 0.014183837234539372
# Kata "remember" memiliki nilai rata-rata TF-IDF 0.014264345818675226
# Kata "won" memiliki nilai rata-rata TF-IDF 0.014643739737808806
# Kata "goes" memiliki nilai rata-rata TF-IDF 0.014723504534276718
# Kata "knew" memiliki nilai rata-rata TF-IDF 0.014835173520985774
# Kata "favorite" memiliki nilai rata-rata TF-IDF 0.01523841683871824
# Kata "eyes" memiliki nilai rata-rata TF-IDF 0.015545422345013713
# Kata "try" memiliki nilai rata-rata TF-IDF 0.01560294784856386
# Kata "end" memiliki nilai rata-rata TF-IDF 0.01609759734928195
# Kata "need" memiliki nilai rata-rata TF-IDF 0.016265427554129956
# Kata "start" memiliki nilai rata-rata TF-IDF 0.016343405796081203
# Kata "demons" memiliki nilai rata-rata TF-IDF 0.016760221809516886
# Kata "feel" memiliki nilai rata-rata TF-IDF 0.01682984134123932
# Kata "face" memiliki nilai rata-rata TF-IDF 0.01693782696522581
# Kata "lose" memiliki nilai rata-rata TF-IDF 0.017056581283436224
# Kata "reason" memiliki nilai rata-rata TF-IDF 0.017552397127121536
# Kata "heart" memiliki nilai rata-rata TF-IDF 0.017584752191049317
# Kata "hope" memiliki nilai rata-rata TF-IDF 0.017877833202189237
# Kata "world" memiliki nilai rata-rata TF-IDF 0.017970212411272106
# Kata "best" memiliki nilai rata-rata TF-IDF 0.018509817226625806
# Kata "make" memiliki nilai rata-rata TF-IDF 0.018537078728145848
# Kata "goodbye" memiliki nilai rata-rata TF-IDF 0.01860802874667403
# Kata "hide" memiliki nilai rata-rata TF-IDF 0.01865653718632926
# Kata "girl" memiliki nilai rata-rata TF-IDF 0.019199281963376495
# Kata "ooh" memiliki nilai rata-rata TF-IDF 0.019253707293120204
# Kata "away" memiliki nilai rata-rata TF-IDF 0.020285297037455928
# Kata "think" memiliki nilai rata-rata TF-IDF 0.020776228530371307
# Kata "said" memiliki nilai rata-rata TF-IDF 0.02095525603855423
# Kata "right" memiliki nilai rata-rata TF-IDF 0.02103231539058285
# Kata "mind" memiliki nilai rata-rata TF-IDF 0.0211202943960363
# Kata "day" memiliki nilai rata-rata TF-IDF 0.02126391322521586
# Kata "want" memiliki nilai rata-rata TF-IDF 0.02156878703927498
# Kata "night" memiliki nilai rata-rata TF-IDF 0.02174838384861536
# Kata "stay" memiliki nilai rata-rata TF-IDF 0.021989496329059183
# Kata "tell" memiliki nilai rata-rata TF-IDF 0.022341559047910405
# Kata "na" memiliki nilai rata-rata TF-IDF 0.02335001794013639
# Kata "look" memiliki nilai rata-rata TF-IDF 0.023452162143194732
# Kata "let" memiliki nilai rata-rata TF-IDF 0.026636076100212482
# Kata "ve" memiliki nilai rata-rata TF-IDF 0.027210495078991228
# Kata "baby" memiliki nilai rata-rata TF-IDF 0.02734990044633969
# Kata "gonna" memiliki nilai rata-rata TF-IDF 0.02842100975988852
# Kata "say" memiliki nilai rata-rata TF-IDF 0.02995932233092775
# Kata "time" memiliki nilai rata-rata TF-IDF 0.030297140196691465
# Kata "way" memiliki nilai rata-rata TF-IDF 0.031148223695789276
# Kata "wanna" memiliki nilai rata-rata TF-IDF 0.03160112706768208
# Kata "yeah" memiliki nilai rata-rata TF-IDF 0.032617319067726434
# Kata "come" memiliki nilai rata-rata TF-IDF 0.03470664032994372
# Kata "got" memiliki nilai rata-rata TF-IDF 0.03511362893992455
# Kata "know" memiliki nilai rata-rata TF-IDF 0.039728553384281794
# Kata "cause" memiliki nilai rata-rata TF-IDF 0.0406039380953705
# Kata "like" memiliki nilai rata-rata TF-IDF 0.0424436244761865
# Kata "love" memiliki nilai rata-rata TF-IDF 0.043790092975639655
# Kata "just" memiliki nilai rata-rata TF-IDF 0.044381500871496775
# Kata "oh" memiliki nilai rata-rata TF-IDF 0.046687996768488685
# Kata "don" memiliki nilai rata-rata TF-IDF 0.04862339142081287
# Kata "ll" memiliki nilai rata-rata TF-IDF 0.05004868740197025

# %% [markdown]
# ***Item Similarity***

# %%
from sklearn.metrics.pairwise import cosine_similarity

# menghitung cosine similaruty antar film berdasarkan isinya
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# membuat DataFrame hasil similarity
item_sim = pd.DataFrame(cosine_sim, index=df['Judul'], columns=df['Judul'])
item_sim
# Out:
# Judul              Ocean and Engines   August   Steal My Girl   Robbers   \
# Judul
# Ocean and Engines           1.000000  0.070576        0.021430  0.092945
# August                      0.070576  1.000000        0.015160  0.020093
# Steal My Girl               0.021430  0.015160        1.000000  0.013943
# Robbers                     0.092945  0.020093        0.013943  1.000000
# Pluto Projector             0.114891  0.082059        0.006716  0.121046
# ...                              ...       ...             ...       ...
# Soul To Squeeze             0.104342  0.039712        0.016244  0.101360
# Chemical                    0.035892  0.041380        0.009409  0.024935
# The Actor                   0.073934  0.047405        0.009522  0.179137
# It's my life                0.055841  0.062620        0.008549  0.024744
# Danger line                 0.060989  0.025022        0.014197  0.086079
#
# Judul              Pluto Projector   AMAZING     SHADE       Uno  Untitled  \
# Judul
# Ocean and Engines         0.114891  0.069963  0.054329  0.118124  0.090686
# August                    0.082059  0.079251  0.028249  0.059977  0.078740
# Steal My Girl             0.006716  0.010663  0.003238  0.020711  0.011220
# Robbers                   0.121046  0.145493  0.008376  0.058740  0.040717
# Pluto Projector           1.000000  0.189864  0.049402  0.129286  0.099778
# ...                            ...       ...       ...       ...       ...
# Soul To Squeeze           0.099509  0.079438  0.054280  0.101692  0.093060
# Chemical                  0.050024  0.044974  0.002455  0.068275  0.050836
# The Actor                 0.071098  0.089960  0.074775  0.073242  0.061227
# It's my life              0.077277  0.034319  0.062813  0.183821  0.104282
# Danger line               0.087000  0.020131  0.017640  0.079630  0.044868
#
# Judul              Can i Open a window  ...  Favorite Girl  Sleep Well  \
# Judul                                   ...
# Ocean and Engines             0.031113  ...       0.032505    0.049966
# August                        0.039582  ...       0.014955    0.005543
# Steal My Girl                 0.007090  ...       0.025882    0.012974
# Robbers                       0.017431  ...       0.012191    0.030071
# Pluto Projector               0.072140  ...       0.011204    0.094549
# ...                                ...  ...            ...         ...
# Soul To Squeeze               0.027456  ...       0.014830    0.044881
# Chemical                      0.028559  ...       0.007588    0.013125
# The Actor                     0.036501  ...       0.032146    0.034150
# It's my life                  0.107779  ...       0.082352    0.039029
# Danger line                   0.030964  ...       0.039518    0.062057
#
# Judul               August    SkyFall   Starman  Soul To Squeeze  Chemical  \
# Judul
# Ocean and Engines  0.070576  0.021204  0.032777         0.104342  0.035892
# August             1.000000  0.008314  0.044914         0.039712  0.041380
# Steal My Girl      0.015160  0.004637  0.008021         0.016244  0.009409
# Robbers            0.020093  0.019480  0.027662         0.101360  0.024935
# Pluto Projector    0.082059  0.013264  0.028355         0.099509  0.050024
# ...                     ...       ...       ...              ...       ...
# Soul To Squeeze    0.039712  0.034258  0.044903         1.000000  0.111393
# Chemical           0.041380  0.053005  0.062885         0.111393  1.000000
# The Actor          0.047405  0.005127  0.019330         0.071170  0.047896
# It's my life       0.062620  0.050455  0.028064         0.072656  0.024666
# Danger line        0.025022  0.004358  0.022735         0.046723  0.031205
#
# Judul              The Actor  It's my life  Danger line
# Judul
# Ocean and Engines   0.073934      0.055841     0.060989
# August              0.047405      0.062620     0.025022
# Steal My Girl       0.009522      0.008549     0.014197
# Robbers             0.179137      0.024744     0.086079
# Pluto Projector     0.071098      0.077277     0.087000
# ...                      ...           ...          ...
# Soul To Squeeze     0.071170      0.072656     0.046723
# Chemical            0.047896      0.024666     0.031205
# The Actor           1.000000      0.021442     0.052304
# It's my life        0.021442      1.000000     0.054660
# Danger line         0.052304      0.054660     1.000000
#
# [78 rows x 78 columns]

# %% [markdown]
# ***Top N Recommendations***

# %%
# lagu yang direkomendasikan Berlian Muhammad G. A
judul_lagu = "Stand Out Fit In"
recom = item_sim[judul_lagu].sort_values(ascending=False)[1:11] # Top 10
print(f"Rekomendasi untuk judul '{judul_lagu}':")
print(recom)
# Out:
# Rekomendasi untuk judul 'Stand Out Fit In':
# Judul
# SkyFall                  0.193074
# Robbers                  0.112705
# Piledriver Waltz         0.077532
# It's my life             0.075267
# Sit Still Look Pretty    0.073721
# You & I                  0.072678
# AMAZING                  0.063241
# Right There              0.063106
# Sleep Well               0.062564
# you & I                  0.061482
# Name: Stand Out Fit In, dtype: float64

# %%
# lagu yang direkomendasikan Bayu Surya Dharma S
judul_lagu = "Fix You"
recom = item_sim[judul_lagu].sort_values(ascending=False)[1:11] # Top 10
print(f"Rekomendasi untuk judul '{judul_lagu}':")
print(recom)
# Out:
# Rekomendasi untuk judul 'Fix You':
# Judul
# You are the reason            0.117132
# Bones                         0.113252
# it will rain                  0.091938
# You & I                       0.091593
# Untitled                      0.071021
# A Place for my head           0.070899
# On Bended Knee                0.069638
# Payphone                      0.069315
# Ocean and Engines             0.068019
# Saving all my love for you    0.065099
# Name: Fix You, dtype: float64
